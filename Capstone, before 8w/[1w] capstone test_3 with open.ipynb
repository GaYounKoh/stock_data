# %% [markdown]
# # 이미 시간순으로 정렬되어있는거라 따로 손 안봐줌.

# %%
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import os
import FinanceDataReader as fdr

import datetime as dt

import numpy as np

from tqdm import tqdm #진행바
from tqdm.notebook import tqdm

# GPU
import tensorflow as tf

#https://www.tensorflow.org/guide/gpu#allowing_gpu_memory_growth
#프로세스의 요구량만큼 메모리 사용 설정
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
if gpus:
    try:
        for i in range(len(gpus)):
            tf.config.experimental.set_memory_growth(gpus[i], True)
    except RuntimeError as e:
        # 프로그램 시작시에 메모리 증가가 설정되어야만 합니다
        print(e)
        
#지정해서 쓰고 싶으면 model 쓸 때는 with 구문 안에 넣기
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# # 방법1) not with open

# %%
# %%time
data = pd.read_csv('stock_2018.csv')
data = data.drop('Index', axis=1)

##
##

col_arr = data.columns.values
col_arr
len(col_arr)

# 설명 idx 필요 없음, 식별변수 필요해서 0번째 열부터 써야함.
목적_idx = np.where(col_arr == 'Next_Change')[0][0] # 목적변수 열 idx

# 사실 굳이 나눌 필요는 없긴 함.
x = pd.concat([data.iloc[:, 0:목적_idx], data.iloc[:,목적_idx+1:]], axis = 1)
y = pd.concat([data.iloc[:, 0:2], data[['Next_Change']]], axis = 1)

##
##

# 여기부터 for문 들어가면 될 것 같음.
# (x[['Trading_Value']] >= 1000_0000_0000).sum() #2682
천억 = x[x['Trading_Value'] >= 1000_0000_0000]
# 천억
# need_date = list(np.sort(천억['Date'].unique()))


# 코드랑 날짜 같이 부르기
cd_dt_dic = {}
for i in range(len(천억[['Code','Date']])):
    
    tmp = 천억[['Code','Date']].iloc[[i]]
    tmp_cd = tmp['Code'].values[0]
    tmp_dt = tmp['Date'].values[0]
    
    # 사전에 key가 이미 있으면 해당 키의 val list에 값 append하기 # 뭔가 함수가 있을 줄 알았는데 없었다. update는 key에 매치된 val값을 새로 바꾸는거..
    if tmp_cd not in cd_dt_dic:
        globals()[f'data_{tmp_cd}'] = [tmp_dt]
        cd_dt_dic[tmp_cd] = globals()[f'data_{tmp_cd}']
    else:
        globals()[f'data_{tmp_cd}'].append(tmp_dt)
        cd_dt_dic[tmp_cd] = globals()[f'data_{tmp_cd}']
# cd_dt_dic
x
# Out:
# CPU times: user 2.36 s, sys: 110 ms, total: 2.47 s
# Wall time: 2.46 s
#          Code        Date   Open   High    Low  Close    Volume  \
# 0       50120  2018-01-02  10250  12050  10150  11800  26086769
# 1       50120  2018-01-03  11950  12450  10900  11750  20460474
# 2       50120  2018-01-04  11850  14150  11600  12600  60663854
# 3       50120  2018-01-05  12800  13200  12000  12200  13935258
# 4       50120  2018-01-08  12450  13400  12350  12850  16471707
# ...       ...         ...    ...    ...    ...    ...       ...
# 380584    540  2018-12-21   4480   4480   4330   4480    109164
# 380585    540  2018-12-24   4480   4530   4440   4520     36973
# 380586    540  2018-12-26   4515   4515   4275   4470     28747
# 380587    540  2018-12-27   4475   4500   4410   4470     20617
# 380588    540  2018-12-28   4500   4825   4440   4705     60012
#
#         Trading_Value    Change      MA5  ...      SRSI      TSI       UO  \
# 0        307823874200  0.145631  10108.0  ...  0.617452  22.3595  45.6450
# 1        240410569500 -0.004237  10538.0  ...  0.606881  24.6104  44.5857
# 2        764364560400  0.072340  11232.0  ...  0.691669  27.8890  46.0102
# 3        170010147600 -0.031746  11730.0  ...  0.605418  28.9426  46.8657
# 4        211661434950  0.053279  12240.0  ...  0.670468  30.8389  48.7672
# ...               ...       ...      ...  ...       ...      ...      ...
# 380584      489054720  0.000000   4573.0  ...  0.000000 -48.1839  40.9134
# 380585      167117960  0.008929   4534.0  ...  0.250801 -48.6931  47.1329
# 380586      128499090 -0.011062   4512.0  ...  0.177769 -49.7125  54.1570
# 380587       92157990  0.000000   4484.0  ...  0.291459 -50.5188  54.6350
# 380588      282356460  0.052573   4529.0  ...  1.000000 -42.8563  62.2204
#
#              SR       WR        AO      KAMA       ROC      PPO       PVO
# 0       73.6842 -26.3158  1259.470   9897.76  44.78530  6.24021  42.05600
# 1       72.7096 -27.2904  1435.350  10067.00  44.17180  7.16213  36.42410
# 2       74.7145 -25.2855  1988.650  10221.40  53.09840  8.40391  42.40620
# 3       67.9276 -32.0724  2473.210  10308.60  51.17720  8.92074  34.04080
# 4       78.6184 -21.3816  2793.380  10359.80  26.60100  9.65555  27.63640
# ...         ...      ...       ...       ...       ...      ...       ...
# 380584  21.4286 -78.5714  -363.397   4592.44 -10.31030 -3.14961   2.96624
# 380585  27.1429 -72.8571  -394.015   4580.40  -8.87097 -3.21322   3.55599
# 380586  27.2727 -72.7273  -422.632   4560.38  -7.83505 -3.31474   2.02404
# 380587  28.4672 -71.5328  -430.515   4538.92  -6.58307 -3.35971  -1.25023
# 380588  73.5043 -26.4957  -402.265   4540.78  -1.36268 -2.95350   5.69357
#
# [380589 rows x 58 columns]

# %%
dday_alldf = pd.DataFrame()

# need_date가 아닌 cd_dt_dic에서 고르기
for k,(key, val) in tqdm(enumerate(cd_dt_dic.items())):
#     key인 동안에
    for i in val:
        if np.where(x[x['Code']==key]['Date'].values == i)[0][0] >= 9 :
            idx = x[x['Code']==key][x['Date']==i].index

            dday_df = pd.DataFrame([x.iloc[:,0:2].loc[idx.values[0]]])
            dday_df.rename(index = {idx.values[0] : i}, inplace = True) # dday_df의 code와 같은 code인 df(x)중에서 고르기

            for j in range(9, -1, -1):

                tmp = x.iloc[idx-j].iloc[:,2:]
                tmp.columns = [f'D-{j}_{ori_col}' for ori_col in x.iloc[:,2:].columns]
                tmp = tmp.rename(index = {idx.values[0]-j : i})
        
                dday_df = pd.concat([dday_df, tmp], axis = 1)

            dday_df = pd.concat([dday_df, y.iloc[idx]['Next_Change'].rename(index = {idx.values[0]:i})], axis = 1)
            dday_alldf = pd.concat([dday_alldf, dday_df])

# %% [markdown]
# # 방법2) with open

# %%
# %%time
cd_dt_dic = {}
x_df = []
y_df = []

f = open('stock_2018.csv')
lines = f.readlines()
for i,line in tqdm(enumerate(lines)):
    line = line.strip()
    lst = np.array(line.split(','))
    lst = lst[1:]
#     while i>=0:
#         lst = np.array(line.split(','))
#         lst
#         break

#     if i>=2:
#         break
# #     break

#################################################### 위가 원하는 결과, 아래는 비슷함.

#     if i == 0:
#         lst = np.array(line.split(','))
#         lst
#         break
#     elif i > 2 :
#         break
# #     break

    if i == 0 : # colname에서 원하는 거 (Next_Change idx) 뽑아서 변수에 저장. ; i==0일 때 lst == 위에서의 data.columns.values
#         lst == col_arr
#         set(lst) - set(col_arr)
#         col_arr
#         lst
        목적_idx = np.where(lst == 'Next_Change')[0][0] # 목적변수 열 idx
#         목적_idx
        x0 = np.append(lst[0:목적_idx], lst[목적_idx+1:])
        y0 = np.append(lst[0:2], lst[목적_idx])
        
        TV_idx = np.where(x0 == 'Trading_Value')[0][0] # 조건에 쓸 TV idx
#         TV_idx
        
#         x_df.append(x0) # 헤더로 ㄱㄱ
#         y_df.append(y0) # 헤더로 ㄱㄱ
    
    else: # elif i <= 10:
#         len(lst) # col_srr랑 col 수 맞춰줌.
#         len(np.append(lst[0:목적_idx], lst[목적_idx+1:])) #58이 맞음.
        x1 = np.append(lst[0:목적_idx], lst[목적_idx+1:])
        y1 = np.append(lst[0:2], lst[목적_idx])
        
        x_df.append(x1)
        y_df.append(y1)
        
#         x1[TV_idx] #문자로 인식됨.
        if int(x1[TV_idx]) >= 1000_0000_0000:
            # 코드랑 날짜 같이 부르기
            tmp_cd = x1[0]
            tmp_dt = x1[1]
        
            # 사전에 key가 이미 있으면 해당 키의 val list에 값 append하기
            if tmp_cd not in cd_dt_dic: # cd_dt_dic = {} 위치가 아예 밖에 있어야지... 안에 있음 초기화되니까....
                globals()[f'data_{tmp_cd}'] = [tmp_dt]
                cd_dt_dic[tmp_cd] = globals()[f'data_{tmp_cd}']

            else:
                globals()[f'data_{tmp_cd}'].append(tmp_dt)
                cd_dt_dic[tmp_cd] = globals()[f'data_{tmp_cd}']
    
#     else:
#         break
        

f.close()
# cd_dt_dic
# Out:
# 0it [00:00, ?it/s]
# CPU times: user 7.03 s, sys: 588 ms, total: 7.62 s
# Wall time: 7.49 s

# %%
# 확인 cell
# data_050120.append('2019')
# data_050120
# cd_dt_dic
# np.array(x_df)
x_df = pd.DataFrame(x_df, columns = x0)
y_df = pd.DataFrame(y_df, columns = y0)
# x_df[0]
# y_df
# Out:
# {'050120': ['2018-01-02',
#   '2018-01-03',
#   '2018-01-04',
#   '2018-01-05',
#   '2018-01-08',
#   '2018-01-10',
#   '2018-01-11',
#   '2018-01-12',
#   '2018-01-15',
#   '2018-01-16',
#   '2018-01-17',
#   '2018-01-18',
#   '2018-01-19',
#   '2018-01-22',
#   '2018-01-23',
#   '2018-01-24',
#   '2018-01-25',
#   '2018-01-26',
#   '2018-01-29',
#   '2018-01-30',
#   '2018-01-31',
#   '2018-02-01',
#   '2018-02-02',
#   '2018-02-05',
#   '2018-02-06',
#   '2018-02-07',
#   '2018-02-12',
#   '2018-02-19',
#   '2018-02-21',
#   '2018-02-26',
#   '2018-04-10',
#   '2018-04-17',
#   '2018-04-18',
#   '2018-04-19',
#   '2018-04-20',
#   '2018-04-24',
#   '2018-04-25',
#   '2018-05-03'],
#  '067290': ['2018-04-11', '2018-04-12'],
#  '036120': ['2018-01-23', '2018-01-24', '2018-01-25'],
#  '078130': ['2018-01-11',
#   '2018-04-17',
#   '2018-05-18',
#   '2018-05-21',
#   '2018-06-21',
#   '2018-06-25',
#   '2018-12-18'],
#  '095660': ['2018-01-24', '2018-05-31'],
#  '007390': ['2018-01-05',
#   '2018-01-16',
#   '2018-01-18',
#   '2018-01-19',
#   '2018-01-22',
#   '2018-01-24',
#   '2018-01-25',
#   '2018-02-05',
#   '2018-02-07',
#   '2018-02-08',
#   '2018-02-09',
#   '2018-03-07',
#   '2018-03-12',
#   '2018-03-13',
#   '2018-03-14',
#   '2018-03-16',
#   '2018-03-19',
#   '2018-03-20',
#   '2018-03-21',
#   '2018-03-22',
#   '2018-03-23',
#   '2018-03-26',
#   '2018-03-27',
#   '2018-03-28',
#   '2018-03-29',
#   '2018-03-30',
#   '2018-04-03',
#   '2018-04-11',
#   '2018-04-12',
#   '2018-04-13',
#   '2018-04-16',
#   '2018-04-17',
#   '2018-04-18',
#   '2018-04-19',
#   '2018-04-20',
#   '2018-04-23',
#   '2018-04-24',
#   '2018-04-25',
#   '2018-04-30',
#   '2018-05-09',
#   '2018-05-11',
#   '2018-05-25',
#   '2018-06-14',
#   '2018-06-15',
#   '2018-06-20',
#   '2018-07-19',
#   '2018-07-20',
#   '2018-08-03',
#   '2018-08-06',
#   '2018-08-07',
#   '2018-09-05',
#   '2018-09-06',
#   '2018-09-07',
#   '2018-09-10',
#   '2018-09-11',
#   '2018-09-12',
#   '2018-09-14',
#   '2018-09-17',
#   '2018-09-18',
#   '2018-09-19',
#   '2018-09-20',
#   '2018-09-28',
#   '2018-10-05',
#   '2018-10-15',
#   '2018-11-01'],
#  '203650': ['2018-01-18', '2018-04-16'],
#  '196490': ['2018-11-01', '2018-11-27'],
#  '078160': ['2018-03-21'],
#  '068940': ['2018-01-22'],
#  '021080': ['2018-01-03',
#   '2018-01-05',
#   '2018-01-08',
#   '2018-01-09',
#   '2018-01-10',
#   '2018-01-19',
#   '2018-01-29',
#   '2018-01-30',
#   '2018-01-31',
#   '2018-02-01',
#   '2018-02-02',
#   '2018-02-07',
#   '2018-02-13'],
#  '101400': ['2018-03-15', '2018-04-17', '2018-04-27'],
#  '049480': ['2018-01-18'],
#  '065950': ['2018-04-27',
#   '2018-04-30',
#   '2018-05-15',
#   '2018-06-05',
#   '2018-06-11',
#   '2018-06-12',
#   '2018-06-14'],
#  '036090': ['2018-01-04',
#   '2018-01-08',
#   '2018-01-30',
#   '2018-01-31',
#   '2018-02-01'],
#  '052300': ['2018-05-16', '2018-05-17', '2018-06-11'],
#  '042040': ['2018-03-30', '2018-04-10', '2018-04-11', '2018-04-16'],
#  '082660': ['2018-06-19', '2018-06-21', '2018-10-05'],
#  '102940': ['2018-11-19', '2018-11-20'],
#  '200230': ['2018-01-03',
#   '2018-01-05',
#   '2018-01-09',
#   '2018-01-18',
#   '2018-02-02',
#   '2018-03-13',
#   '2018-03-16',
#   '2018-03-19',
#   '2018-03-26',
#   '2018-03-27',
#   '2018-03-28',
#   '2018-03-29',
#   '2018-03-30',
#   '2018-04-02',
#   '2018-04-03',
#   '2018-04-10',
#   '2018-05-09',
#   '2018-05-18',
#   '2018-10-19',
#   '2018-11-06'],
#  '203690': ['2018-04-06',
#   '2018-04-09',
#   '2018-04-10',
#   '2018-04-11',
#   '2018-05-24',
#   '2018-08-07'],
#  '048410': ['2018-09-14', '2018-09-17', '2018-09-18'],
#  '039610': ['2018-06-14', '2018-09-03'],
#  '090710': ['2018-07-16'],
#  '067630': ['2018-04-11'],
#  '014200': ['2018-04-20'],
#  '091590': ['2018-04-20'],
#  '104040': ['2018-05-24', '2018-05-29'],
#  '045390': ['2018-04-04',
#   '2018-04-19',
#   '2018-04-27',
#   '2018-05-02',
#   '2018-05-03',
#   '2018-05-04',
#   '2018-05-08',
#   '2018-05-09',
#   '2018-05-10',
#   '2018-05-11',
#   '2018-05-14',
#   '2018-05-15',
#   '2018-05-16',
#   '2018-05-17',
#   '2018-05-18',
#   '2018-05-23',
#   '2018-05-24',
#   '2018-05-25',
#   '2018-05-29',
#   '2018-05-30',
#   '2018-05-31',
#   '2018-06-01',
#   '2018-06-04',
#   '2018-06-05',
#   '2018-06-07',
#   '2018-06-08',
#   '2018-06-11',
#   '2018-06-12',
#   '2018-06-14',
#   '2018-06-15',
#   '2018-06-18',
#   '2018-06-19',
#   '2018-06-20',
#   '2018-06-21',
#   '2018-06-22',
#   '2018-06-25',
#   '2018-06-26',
#   '2018-06-27',
#   '2018-06-28',
#   '2018-06-29',
#   '2018-07-03',
#   '2018-07-06',
#   '2018-07-09',
#   '2018-07-11',
#   '2018-07-24',
#   '2018-07-25',
#   '2018-07-26',
#   '2018-08-10',
#   '2018-08-13',
#   '2018-08-14',
#   '2018-08-16',
#   '2018-08-17',
#   '2018-08-23',
#   '2018-08-27',
#   '2018-09-06',
#   '2018-09-10',
#   '2018-09-17',
#   '2018-09-18',
#   '2018-09-19',
#   '2018-09-20',
#   '2018-10-30',
#   '2018-11-23',
#   '2018-11-26',
#   '2018-12-07',
#   '2018-12-13',
#   '2018-12-21'],
#  '085370': ['2018-03-15'],
#  '220630': ['2018-06-28'],
#  '133750': ['2018-05-25', '2018-06-01'],
#  '065650': ['2018-04-13', '2018-04-16', '2018-07-20'],
#  '059210': ['2018-04-16', '2018-04-17'],
#  '038500': ['2018-05-14'],
#  '017510': ['2018-05-17', '2018-05-18', '2018-05-29'],
#  '101390': ['2018-08-09'],
#  '052420': ['2018-01-02',
#   '2018-01-03',
#   '2018-01-04',
#   '2018-01-05',
#   '2018-01-08',
#   '2018-01-09',
#   '2018-01-10',
#   '2018-01-11',
#   '2018-01-12',
#   '2018-01-15',
#   '2018-01-17',
#   '2018-01-19',
#   '2018-02-01',
#   '2018-02-02'],
#  '066590': ['2018-03-12', '2018-03-13', '2018-04-18'],
#  '048530': ['2018-11-20'],
#  '023440': ['2018-07-18', '2018-07-19'],
#  '114120': ['2018-01-11',
#   '2018-01-12',
#   '2018-01-23',
#   '2018-01-29',
#   '2018-01-31',
#   '2018-02-01',
#   '2018-02-21',
#   '2018-02-22',
#   '2018-02-23',
#   '2018-02-26',
#   '2018-02-27',
#   '2018-02-28',
#   '2018-03-02',
#   '2018-03-05',
#   '2018-03-06',
#   '2018-03-12',
#   '2018-03-13',
#   '2018-03-14',
#   '2018-03-29',
#   '2018-04-16',
#   '2018-04-26'],
#  '191420': ['2018-07-30'],
#  '066700': ['2018-03-21', '2018-04-26', '2018-05-18'],
#  '053300': ['2018-01-17', '2018-01-18'],
#  '184230': ['2018-02-05', '2018-02-06'],
#  '014570': ['2018-02-06', '2018-02-07', '2018-02-09', '2018-09-28'],
#  '090360': ['2018-05-30', '2018-06-28'],
#  '036630': ['2018-05-03'],
#  '097780': ['2018-04-16',
#   '2018-04-17',
#   '2018-04-18',
#   '2018-04-27',
#   '2018-05-02',
#   '2018-07-03',
#   '2018-07-04'],
#  '069080': ['2018-01-04', '2018-01-05', '2018-03-21'],
#  '024810': ['2018-01-02',
#   '2018-01-03',
#   '2018-01-04',
#   '2018-01-05',
#   '2018-01-08',
#   '2018-01-09',
#   '2018-01-10',
#   '2018-03-05',
#   '2018-03-07',
#   '2018-03-08',
#   '2018-03-09',
#   '2018-03-12',
#   '2018-03-19',
#   '2018-03-28',
#   '2018-03-29',
#   '2018-04-06',
#   '2018-04-18',
#   '2018-04-19',
#   '2018-04-20',
#   '2018-04-23',
#   '2018-04-24',
#   '2018-04-25',
#   '2018-04-26',
#   '2018-04-27',
#   '2018-04-30',
#   '2018-05-02',
#   '2018-05-03',
#   '2018-05-04',
#   '2018-05-08',
#   '2018-05-09',
#   '2018-05-10',
#   '2018-05-11',
#   '2018-05-14',
#   '2018-05-15',
#   '2018-05-16',
#   '2018-05-17',
#   '2018-05-24',
#   '2018-05-25',
#   '2018-05-28',
#   '2018-05-29',
#   '2018-05-30',
#   '2018-06-01',
#   '2018-06-12',
#   '2018-09-06',
#   '2018-12-24'],
#  '049630': ['2018-03-08', '2018-04-18', '2018-04-19'],
#  '047820': ['2018-11-08'],
#  '224060': ['2018-04-03', '2018-04-10', '2018-04-11', '2018-05-21'],
#  '099220': ['2018-05-03'],
#  '006920': ['2018-02-20'],
#  '053030': ['2018-04-09', '2018-04-11'],
#  '086040': ['2018-01-17'],
#  '000250': ['2018-01-11', '2018-02-20', '2018-02-21', '2018-04-06'],
#  '222080': ['2018-02-26', '2018-03-14', '2018-06-25'],
#  '046120': ['2018-04-20',
#   '2018-04-27',
#   '2018-04-30',
#   '2018-05-23',
#   '2018-05-24',
#   '2018-06-12'],
#  '033100': ['2018-03-08',
#   '2018-03-09',
#   '2018-03-28',
#   '2018-03-29',
#   '2018-04-13',
#   '2018-04-17',
#   '2018-04-18',
#   '2018-04-19',
#   '2018-09-06'],
#  '065060': ['2018-01-11', '2018-12-19'],
#  '192250': ['2018-01-25'],
#  '217600': ['2018-03-30'],
#  '029960': ['2018-10-10'],
#  '034230': ['2018-01-17', '2018-04-02', '2018-04-03'],
#  '028300': ['2018-03-23',
#   '2018-03-26',
#   '2018-03-28',
#   '2018-04-04',
#   '2018-04-06',
#   '2018-04-09',
#   '2018-04-10',
#   '2018-05-09',
#   '2018-05-10',
#   '2018-05-25',
#   '2018-05-29',
#   '2018-05-30',
#   '2018-05-31',
#   '2018-06-04',
#   '2018-06-05',
#   '2018-06-12',
#   '2018-08-09',
#   '2018-08-14',
#   '2018-10-12'],
#  '047920': ['2018-02-05', '2018-02-14'],
#  '038290': ['2018-01-18', '2018-01-23', '2018-01-24'],
#  '225530': ['2018-06-04'],
#  '078860': ['2018-04-24', '2018-04-25'],
#  '053800': ['2018-02-20',
#   '2018-02-21',
#   '2018-02-22',
#   '2018-03-06',
#   '2018-03-29',
#   '2018-03-30'],
#  '193250': ['2018-05-25', '2018-05-28', '2018-05-29', '2018-05-30'],
#  '011320': ['2018-12-18'],
#  '001840': ['2018-03-09',
#   '2018-03-23',
#   '2018-04-19',
#   '2018-04-20',
#   '2018-04-23'],
#  '068330': ['2018-04-10'],
#  '041460': ['2018-01-18'],
#  '064240': ['2018-03-22'],
#  '214270': ['2018-02-09'],
#  '035900': ['2018-01-17', '2018-05-02', '2018-10-24', '2018-10-26'],
#  '033640': ['2018-06-19', '2018-06-20'],
#  '060570': ['2018-01-31', '2018-02-22', '2018-05-29', '2018-05-30'],
#  '090460': ['2018-01-18'],
#  '065450': ['2018-05-16', '2018-05-17', '2018-05-25'],
#  '038070': ['2018-04-10'],
#  '071670': ['2018-01-09'],
#  '061970': ['2018-05-25',
#   '2018-05-28',
#   '2018-06-01',
#   '2018-06-04',
#   '2018-06-05',
#   '2018-07-31',
#   '2018-08-01',
#   '2018-08-03',
#   '2018-08-14',
#   '2018-08-16',
#   '2018-09-04',
#   '2018-09-05',
#   '2018-12-18'],
#  '095190': ['2018-04-19'],
#  '095700': ['2018-01-11', '2018-01-12', '2018-01-15'],
#  '166480': ['2018-03-27', '2018-04-10', '2018-04-13'],
#  '054780': ['2018-02-02',
#   '2018-03-13',
#   '2018-03-14',
#   '2018-03-15',
#   '2018-03-16',
#   '2018-03-20',
#   '2018-04-09',
#   '2018-05-25',
#   '2018-05-29',
#   '2018-05-30',
#   '2018-05-31',
#   '2018-06-01',
#   '2018-06-04',
#   '2018-06-05',
#   '2018-06-07',
#   '2018-07-05',
#   '2018-07-31',
#   '2018-08-01',
#   '2018-08-13',
#   '2018-08-14',
#   '2018-08-16',
#   '2018-08-20',
#   '2018-08-21',
#   '2018-08-22',
#   '2018-08-23',
#   '2018-08-24',
#   '2018-08-27',
#   '2018-08-28',
#   '2018-08-29',
#   '2018-08-30',
#   '2018-08-31',
#   '2018-09-03',
#   '2018-09-04',
#   '2018-09-05',
#   '2018-09-06',
#   '2018-09-07',
#   '2018-09-10',
#   '2018-09-11',
#   '2018-09-12',
#   '2018-09-19',
#   '2018-09-21',
#   '2018-09-28',
#   '2018-10-01',
#   '2018-10-02',
#   '2018-10-08',
#   '2018-10-10',
#   '2018-10-11',
#   '2018-10-12',
#   '2018-10-15',
#   '2018-10-17',
#   '2018-10-18',
#   '2018-10-19',
#   '2018-10-22',
#   '2018-10-23',
#   '2018-10-24',
#   '2018-10-25',
#   '2018-10-30',
#   '2018-10-31',
#   '2018-11-02',
#   '2018-11-09',
#   '2018-11-12',
#   '2018-11-13',
#   '2018-11-14'],
#  '058820': ['2018-01-02',
#   '2018-01-03',
#   '2018-01-05',
#   '2018-01-12',
#   '2018-01-18',
#   '2018-01-24',
#   '2018-01-25',
#   '2018-03-15',
#   '2018-03-23',
#   '2018-03-27',
#   '2018-09-20'],
#  '114450': ['2018-03-16', '2018-09-19'],
#  '019550': ['2018-01-08',
#   '2018-02-01',
#   '2018-02-02',
#   '2018-02-05',
#   '2018-02-07',
#   '2018-02-13'],
#  '068240': ['2018-04-30'],
#  '027830': ['2018-01-05', '2018-01-30', '2018-02-01', '2018-02-02'],
#  '092600': ['2018-08-03', '2018-08-08'],
#  '052020': ['2018-02-19', '2018-09-19'],
#  '086520': ['2018-01-16', '2018-10-23', '2018-11-01'],
#  '032820': ['2018-04-27',
#   '2018-04-30',
#   '2018-05-03',
#   '2018-05-08',
#   '2018-05-10',
#   '2018-07-27'],
#  '041190': ['2018-01-02',
#   '2018-01-03',
#   '2018-01-05',
#   '2018-01-09',
#   '2018-01-10',
#   '2018-01-11',
#   '2018-01-12',
#   '2018-01-15',
#   '2018-01-16',
#   '2018-01-17',
#   '2018-01-18',
#   '2018-01-19',
#   '2018-01-22',
#   '2018-01-23',
#   '2018-01-24',
#   '2018-01-25',
#   '2018-01-29',
#   '2018-01-30',
#   '2018-02-01',
#   '2018-02-07',
#   '2018-02-21',
#   '2018-04-24',
#   '2018-04-25',
#   '2018-04-27',
#   '2018-07-17',
#   '2018-07-18',
#   '2018-07-20',
#   '2018-07-25',
#   '2018-08-22'],
#  '023410': ['2018-05-28'],
#  '147830': ['2018-03-08', '2018-03-28'],
#  '204840': ['2018-06-08'],
#  '036170': ['2018-01-11', '2018-01-26', '2018-01-29', '2018-01-31'],
#  '084990': ['2018-01-12',
#   '2018-01-15',
#   '2018-01-16',
#   '2018-01-17',
#   '2018-01-18',
#   '2018-01-19',
#   '2018-01-22',
#   '2018-01-23',
#   '2018-01-24',
#   '2018-01-25',
#   '2018-01-26',
#   '2018-01-29',
#   '2018-01-30',
#   '2018-01-31',
#   '2018-02-01',
#   '2018-02-02',
#   '2018-02-05',
#   '2018-02-06',
#   '2018-02-07',
#   '2018-02-08',
#   '2018-02-09',
#   '2018-02-12',
#   '2018-02-13',
#   '2018-02-28',
#   '2018-03-23',
#   '2018-04-04',
#   '2018-04-09',
#   '2018-04-10',
#   '2018-04-12',
#   '2018-05-23',
#   '2018-05-24',
#   '2018-05-25',
#   '2018-05-29',
#   '2018-05-30',
#   '2018-05-31',
#   '2018-07-05',
#   '2018-09-20',
#   '2018-12-26',
#   '2018-12-27'],
#  '048470': ['2018-09-05'],
#  '066410': ['2018-03-08',
#   '2018-04-18',
#   '2018-05-17',
#   '2018-05-18',
#   '2018-05-23',
#   '2018-05-24',
#   '2018-05-28',
#   '2018-05-31',
#   '2018-06-19',
#   '2018-06-20',
#   '2018-06-22',
#   '2018-07-03'],
#  '006910': ['2018-02-22', '2018-04-20', '2018-04-23', '2018-05-03'],
#  '035890': ['2018-06-12',
#   '2018-06-14',
#   '2018-06-15',
#   '2018-07-30',
#   '2018-07-31'],
#  '068760': ['2018-01-03',
#   '2018-01-04',
#   '2018-01-08',
#   '2018-01-09',
#   '2018-01-11',
#   '2018-01-12',
#   '2018-01-15',
#   '2018-01-16',
#   '2018-01-17',
#   '2018-01-18',
#   '2018-01-19',
#   '2018-01-22',
#   '2018-01-23',
#   '2018-01-24',
#   '2018-01-29',
#   '2018-01-30',
#   '2018-02-08',
#   '2018-04-05',
#   '2018-04-09',
#   '2018-05-31',
#   '2018-11-16',
#   '2018-11-19'],
#  '025980': ['2018-05-17',
#   '2018-05-21',
#   '2018-06-01',
#   '2018-06-18',
#   '2018-06-19',
#   '2018-06-20',
#   '2018-09-21',
#   '2018-10-04',
#   '2018-12-11',
#   '2018-12-12',
#   '2018-12-13',
#   '2018-12-14',
#   '2018-12-17',
#   '2018-12-18',
#   '2018-12-24',
#   '2018-12-26',
#   '2018-12-27',
#   '2018-12-28'],
#  '119830': ['2018-06-20'],
#  '109610': ['2018-04-20'],
#  '039200': ['2018-04-04', '2018-11-05', '2018-11-06'],
#  '215380': ['2018-03-22',
#   '2018-03-23',
#   '2018-04-10',
#   '2018-05-16',
#   '2018-05-17'],
#  '014190': ['2018-08-31'],
#  '043910': ['2018-05-04'],
#  '007370': ['2018-02-09'],
#  '085660': ['2018-01-02',
#   '2018-01-03',
#   '2018-01-04',
#   '2018-01-05',
#   '2018-01-08',
#   '2018-01-09',
#   '2018-01-10',
#   '2018-01-12',
#   '2018-01-16',
#   '2018-01-17',
#   '2018-01-19',
#   '2018-01-26',
#   '2018-02-01',
#   '2018-02-02',
#   '2018-02-06',
#   '2018-02-07',
#   '2018-02-08',
#   '2018-02-09',
#   '2018-02-12',
#   '2018-02-20',
#   '2018-02-26',
#   '2018-03-08',
#   '2018-03-12',
#   '2018-03-14',
#   '2018-03-16',
#   '2018-03-19',
#   '2018-03-20',
#   '2018-03-21',
#   '2018-03-22',
#   '2018-03-26',
#   '2018-03-27',
#   '2018-03-28',
#   '2018-03-30',
#   '2018-04-02',
#   '2018-04-05',
#   '2018-04-06',
#   '2018-04-12',
#   '2018-04-18',
#   '2018-09-20'],
#  '039420': ['2018-01-15', '2018-01-17'],
#  '081150': ['2018-05-08', '2018-09-13'],
#  '009520': ['2018-04-25',
#   '2018-04-26',
#   '2018-06-07',
#   '2018-09-10',
#   '2018-09-11',
#   '2018-09-18',
#   '2018-09-19',
#   '2018-09-27'],
#  '094940': ['2018-05-17',
#   '2018-05-23',
#   '2018-05-29',
#   '2018-05-30',
#   '2018-08-10',
#   '2018-09-04',
#   '2018-09-19'],
#  '032860': ['2018-01-31',
#   '2018-06-22',
#   '2018-06-25',
#   '2018-06-28',
#   '2018-08-20'],
#  '000210': ['2018-01-26', '2018-08-08'],
#  '011200': ['2018-01-02',
#   '2018-04-05',
#   '2018-04-06',
#   '2018-04-23',
#   '2018-04-30',
#   '2018-05-02',
#   '2018-05-14',
#   '2018-05-15',
#   '2018-05-16',
#   '2018-05-28',
#   '2018-09-19'],
#  '092220': ['2018-05-31'],
#  '011070': ['2018-01-09',
#   '2018-01-19',
#   '2018-05-28',
#   '2018-08-24',
#   '2018-09-13'],
#  '010060': ['2018-01-04',
#   '2018-01-05',
#   '2018-01-10',
#   '2018-01-11',
#   '2018-01-24',
#   '2018-02-01',
#   '2018-02-06',
#   '2018-03-22',
#   '2018-04-25',
#   '2018-06-04'],
#  '096770': ['2018-01-29',
#   '2018-02-26',
#   '2018-05-02',
#   '2018-05-31',
#   '2018-07-02',
#   '2018-10-01'],
#  '002100': ['2018-06-18'],
#  '008350': ['2018-05-09',
#   '2018-05-11',
#   '2018-11-05',
#   '2018-11-07',
#   '2018-12-03',
#   '2018-12-04',
#   '2018-12-05',
#   '2018-12-10',
#   '2018-12-12',
#   '2018-12-14'],
#  '047040': ['2018-01-11'],
#  '017180': ['2018-02-05',
#   '2018-02-06',
#   '2018-02-07',
#   '2018-02-09',
#   '2018-02-20',
#   '2018-02-21',
#   '2018-03-22'],
#  '006400': ['2018-01-05',
#   '2018-01-19',
#   '2018-01-22',
#   '2018-01-23',
#   '2018-01-24',
#   '2018-01-25',
#   '2018-01-31',
#   '2018-02-01',
#   '2018-02-02',
#   '2018-02-05',
#   '2018-02-06',
#   '2018-02-07',
#   '2018-03-09',
#   '2018-03-12',
#   '2018-03-14',
#   '2018-03-15',
#   '2018-03-16',
#   '2018-03-19',
#   '2018-04-02',
#   '2018-05-23',
#   '2018-06-04',
#   '2018-06-07',
#   '2018-06-12',
#   '2018-06-14',
#   '2018-06-15',
#   '2018-06-18',
#   '2018-06-19',
#   '2018-06-20',
#   '2018-06-29',
#   '2018-07-06',
#   '2018-07-12',
#   '2018-07-13',
#   '2018-07-25',
#   '2018-07-30',
#   '2018-08-10',
#   '2018-09-03',
#   '2018-09-11',
#   '2018-09-12',
#   '2018-09-13',
#   '2018-09-18',
#   '2018-10-05',
#   '2018-10-12',
#   '2018-10-23',
#   '2018-10-24',
#   '2018-10-25',
#   '2018-10-26',
#   '2018-10-29',
#   '2018-10-30',
#   '2018-11-01',
#   '2018-11-02',
#   '2018-11-08',
#   '2018-11-09',
#   '2018-11-13',
#   '2018-11-20',
#   '2018-11-21',
#   '2018-12-03',
#   '2018-12-13',
#   '2018-12-21'],
#  '028050': ['2018-01-10',
#   '2018-01-26',
#   '2018-02-08',
#   '2018-03-12',
#   '2018-03-13',
#   '2018-05-15',
#   '2018-05-21',
#   '2018-05-31',
#   '2018-06-01'],
#  '055550': ['2018-05-31', '2018-07-26', '2018-09-14', '2018-12-13'],
#  '081000': ['2018-01-23'],
#  '001550': ['2018-06-12', '2018-06-15'],
#  '005490': ['2018-01-03',
#   '2018-01-04',
#   '2018-01-12',
#   '2018-01-25',
#   '2018-01-30',
#   '2018-02-01',
#   '2018-02-06',
#   '2018-02-08',
#   '2018-02-09',
#   '2018-02-28',
#   '2018-03-02',
#   '2018-03-08',
#   '2018-03-09',
#   '2018-03-14',
#   '2018-03-19',
#   '2018-03-23',
#   '2018-03-26',
#   '2018-03-27',
#   '2018-04-10',
#   '2018-04-18',
#   '2018-04-19',
#   '2018-04-30',
#   '2018-05-02',
#   '2018-05-31',
#   '2018-06-14',
#   '2018-06-19',
#   '2018-07-24',
#   '2018-08-30',
#   '2018-09-05',
#   '2018-09-11',
#   '2018-09-12',
#   '2018-09-13',
#   '2018-09-14',
#   '2018-09-19',
#   '2018-09-21',
#   '2018-09-27',
#   '2018-09-28',
#   '2018-10-04',
#   '2018-10-05',
#   '2018-10-11',
#   '2018-10-30',
#   '2018-11-14',
#   '2018-11-26',
#   '2018-11-28',
#   '2018-11-29',
#   '2018-11-30',
#   '2018-12-03',
#   '2018-12-13'],
#  '009460': ['2018-10-24'],
#  '000720': ['2018-01-29',
#   '2018-03-09',
#   '2018-04-19',
#   '2018-04-20',
#   '2018-04-23',
#   '2018-04-24',
#   '2018-04-25',
#   '2018-04-26',
#   '2018-04-27',
#   '2018-04-30',
#   '2018-05-02',
#   '2018-05-03',
#   '2018-05-04',
#   '2018-05-08',
#   '2018-05-09',
#   '2018-05-10',
#   '2018-05-11',
#   '2018-05-14',
#   '2018-05-15',
#   '2018-05-16',
#   '2018-05-17',
#   '2018-05-18',
#   '2018-05-21',
#   '2018-05-23',
#   '2018-05-24',
#   '2018-05-25',
#   '2018-05-28',
#   '2018-05-29',
#   '2018-05-30',
#   '2018-05-31',
#   '2018-06-01',
#   '2018-06-04',
#   '2018-06-05',
#   '2018-06-07',
#   '2018-06-08',
#   '2018-06-11',
#   '2018-06-12',
#   '2018-06-14',
#   '2018-06-15',
#   '2018-06-18',
#   '2018-06-19',
#   '2018-06-20',
#   '2018-06-21',
#   '2018-06-22',
#   '2018-06-25',
#   '2018-06-26',
#   '2018-06-27',
#   '2018-06-28',
#   '2018-06-29',
#   '2018-07-02',
#   '2018-07-03',
#   '2018-07-05',
#   '2018-07-06',
#   '2018-07-09',
#   '2018-07-11',
#   '2018-07-24',
#   '2018-07-25',
#   '2018-07-26',
#   '2018-08-10',
#   '2018-08-13',
#   '2018-08-23',
#   '2018-08-27',
#   '2018-09-10',
#   '2018-09-11',
#   '2018-09-12',
#   '2018-09-19',
#   '2018-09-21',
#   '2018-10-10',
#   '2018-10-11',
#   '2018-11-07'],
#  '042670': ['2018-01-09', '2018-04-02', '2018-04-30'],
#  '017800': ['2018-03-09',
#   '2018-03-28',
#   '2018-04-19',
#   '2018-04-20',
#   '2018-04-23',
#   '2018-04-30',
#   '2018-05-02',
#   '2018-05-09',
#   '2018-05-10',
#   '2018-05-11',
#   '2018-05-14',
#   '2018-05-15',
#   '2018-05-16',
#   '2018-05-17',
#   '2018-05-18',
#   '2018-05-23',
#   '2018-05-25',
#   '2018-05-28',
#   '2018-05-29',
#   '2018-05-30',
#   '2018-05-31',
#   '2018-06-01',
#   '2018-06-04',
#   '2018-06-05',
#   '2018-06-11',
#   '2018-06-12',
#   '2018-06-14',
#   '2018-07-24',
#   '2018-08-27',
#   '2018-09-19',
#   '2018-09-21',
#   '2018-10-04',
#   '2018-10-10',
#   '2018-10-11',
#   '2018-11-07'],
#  '000120': ['2018-03-16'],
#  '105560': ['2018-02-06',
#   '2018-02-08',
#   '2018-02-26',
#   '2018-03-08',
#   '2018-05-30',
#   '2018-05-31',
#   '2018-08-08',
#   '2018-09-21',
#   '2018-10-04',
#   '2018-10-31',
#   '2018-11-21',
#   '2018-12-13'],
#  '002760': ['2018-03-27',
#   '2018-04-04',
#   '2018-04-05',
#   '2018-04-06',
#   '2018-05-21',
#   '2018-05-23',
#   '2018-06-26',
#   '2018-06-27',
#   '2018-06-29'],
#  '002700': ['2018-07-17', '2018-07-18'],
#  '019170': ['2018-10-01'],
#  '090430': ['2018-03-09',
#   '2018-04-02',
#   '2018-04-03',
#   '2018-06-28',
#   '2018-07-26',
#   '2018-07-27',
#   '2018-10-04',
#   '2018-10-29',
#   '2018-10-30',
#   '2018-11-15',
#   '2018-11-21',
#   '2018-11-22',
#   '2018-11-27',
#   '2018-11-28',
#   '2018-12-12',
#   '2018-12-13'],
#  '036570': ['2018-01-03',
#   '2018-01-04',
#   '2018-01-26',
#   '2018-02-08',
#   '2018-05-10',
#   '2018-05-11',
#   '2018-11-28',
#   '2018-11-29',
#   '2018-12-06',
#   '2018-12-13',
#   '2018-12-21'],
#  '003520': ['2018-01-12', '2018-01-16', '2018-04-04', '2018-04-20'],
#  '161890': ['2018-02-21'],
#  '009420': ['2018-01-03',
#   '2018-01-09',
#   '2018-01-10',
#   '2018-01-11',
#   '2018-01-12',
#   '2018-01-15',
#   '2018-01-16',
#   '2018-01-19',
#   '2018-01-30',
#   '2018-01-31',
#   '2018-02-01',
#   '2018-02-06',
#   '2018-02-20',
#   '2018-03-13',
#   '2018-04-09'],
#  '008770': ['2018-03-09',
#   '2018-04-02',
#   '2018-07-03',
#   '2018-07-09',
#   '2018-07-19',
#   '2018-07-30',
#   '2018-10-04',
#   '2018-10-11',
#   '2018-11-15'],
#  '006360': ['2018-04-09', '2018-04-30', '2018-05-28', '2018-07-26'],
#  '001060': ['2018-04-11'],
#  '066570': ['2018-01-02',
#   '2018-01-04',
#   '2018-01-08',
#   '2018-01-09',
#   '2018-01-23',
#   '2018-01-24',
#   '2018-01-29',
#   '2018-02-06',
#   '2018-02-07',
#   '2018-03-07',
#   '2018-03-13',
#   '2018-03-27',
#   '2018-04-06',
#   '2018-04-10',
#   '2018-04-20',
#   '2018-04-23',
#   '2018-05-08',
#   '2018-05-31',
#   '2018-06-01',
#   '2018-06-14',
#   '2018-06-21',
#   '2018-07-06',
#   '2018-07-17',
#   '2018-07-27',
#   '2018-08-09',
#   '2018-08-14',
#   '2018-08-21',
#   '2018-08-29',
#   '2018-09-18',
#   '2018-09-19',
#   '2018-12-20'],
#  '073240': ['2018-01-03',
#   '2018-03-30',
#   '2018-04-03',
#   '2018-04-04',
#   '2018-04-05'],
#  '008970': ['2018-05-02',
#   '2018-05-29',
#   '2018-06-01',
#   '2018-06-07',
#   '2018-06-12',
#   '2018-06-18'],
#  '027740': ['2018-06-19', '2018-06-22', '2018-06-25'],
#  '018260': ['2018-01-04',
#   '2018-01-08',
#   '2018-01-11',
#   '2018-01-17',
#   '2018-06-15'],
#  '016360': ['2018-04-06', '2018-04-09', '2018-04-10', '2018-04-11'],
#  '006980': ['2018-02-20',
#   '2018-04-20',
#   '2018-05-02',
#   '2018-05-03',
#   '2018-06-01',
#   '2018-06-04',
#   '2018-06-19',
#   '2018-07-06',
#   '2018-07-09'],
#  '139480': ['2018-01-26'],
#  '015760': ['2018-04-03',
#   '2018-04-04',
#   '2018-04-23',
#   '2018-04-30',
#   '2018-05-02'],
#  '047810': ['2018-01-17',
#   '2018-03-21',
#   '2018-07-11',
#   '2018-07-13',
#   '2018-07-18',
#   '2018-07-19',
#   '2018-09-27',
#   '2018-09-28',
#   '2018-10-01',
#   '2018-10-02'],
#  '012450': ['2018-05-31'],
#  '086280': ['2018-03-28', '2018-03-29', '2018-03-30'],
#  '051900': ['2018-01-24', '2018-07-03', '2018-11-13'],
#  '051910': ['2018-01-08',
#   '2018-01-09',
#   '2018-01-24',
#   '2018-02-01',
#   '2018-02-02',
#   '2018-02-05',
#   '2018-02-06',
#   '2018-02-07',
#   '2018-02-08',
#   '2018-03-09',
#   '2018-03-15',
#   '2018-03-28',
#   '2018-04-10',
#   '2018-04-25',
#   '2018-05-02',
#   '2018-05-03',
#   '2018-05-08',
#   '2018-05-14',
#   '2018-05-23',
#   '2018-05-25',
#   '2018-05-30',
#   '2018-05-31',
#   '2018-06-04',
#   '2018-06-05',
#   '2018-06-07',
#   '2018-06-08',
#   '2018-06-11',
#   '2018-06-12',
#   '2018-06-14',
#   '2018-06-15',
#   '2018-06-19',
#   '2018-06-22',
#   '2018-06-27',
#   '2018-06-29',
#   '2018-07-02',
#   '2018-07-12',
#   '2018-07-13',
#   '2018-07-18',
#   '2018-07-19',
#   '2018-07-25',
#   '2018-07-26',
#   '2018-07-27',
#   '2018-08-01',
#   '2018-08-03',
#   '2018-08-06',
#   '2018-08-07',
#   '2018-08-09',
#   '2018-08-21',
#   '2018-08-22',
#   '2018-08-24',
#   '2018-08-27',
#   '2018-09-11',
#   '2018-09-13',
#   '2018-09-18',
#   '2018-10-04',
#   '2018-10-05',
#   '2018-10-11',
#   '2018-10-26',
#   '2018-10-29',
#   '2018-11-07',
#   '2018-11-08',
#   '2018-11-09',
#   '2018-11-28',
#   '2018-11-30',
#   '2018-12-03',
#   '2018-12-21'],
#  '035420': ['2018-10-17',
#   '2018-10-18',
#   '2018-10-19',
#   '2018-10-23',
#   '2018-10-25',
#   '2018-10-26',
#   '2018-10-30',
#   '2018-10-31',
#   '2018-11-02',
#   '2018-11-30',
#   '2018-12-13'],
#  '002360': ['2018-04-26'],
#  '001510': ['2018-07-19'],
#  '069620': ['2018-01-12', '2018-01-24'],
#  '001440': ['2018-05-16', '2018-05-17'],
#  '011170': ['2018-01-08',
#   '2018-02-09',
#   '2018-03-08',
#   '2018-08-22',
#   '2018-09-11',
#   '2018-10-10',
#   '2018-11-02',
#   '2018-12-03'],
#  '011390': ['2018-05-11',
#   '2018-05-29',
#   '2018-05-30',
#   '2018-07-25',
#   '2018-08-10'],
#  '004770': ['2018-02-20', '2018-02-21', '2018-02-22'],
#  '008250': ['2018-05-08'],
#  '006490': ['2018-03-22',
#   '2018-03-23',
#   '2018-03-26',
#   '2018-03-30',
#   '2018-04-02',
#   '2018-04-03',
#   '2018-04-04',
#   '2018-04-05',
#   '2018-04-06',
#   '2018-04-09',
#   '2018-04-10',
#   '2018-04-12',
#   '2018-04-13',
#   '2018-04-16',
#   '2018-04-18',
#   '2018-04-19',
#   '2018-04-20',
#   '2018-04-23',
#   '2018-04-24',
#   '2018-05-02',
#   '2018-05-24',
#   '2018-06-07',
#   '2018-06-08',
#   '2018-06-11',
#   '2018-06-12'],
#  '001020': ['2018-02-02'],
#  '004020': ['2018-04-30',
#   '2018-05-02',
#   '2018-05-10',
#   '2018-05-14',
#   '2018-05-16',
#   '2018-05-28',
#   '2018-05-29',
#   '2018-06-08',
#   '2018-06-12',
#   '2018-06-14'],
#  '034220': ['2018-01-03',
#   '2018-01-12',
#   '2018-01-16',
#   '2018-01-17',
#   '2018-01-18',
#   '2018-01-23',
#   '2018-01-24',
#   '2018-01-25',
#   '2018-01-26',
#   '2018-02-01',
#   '2018-03-27',
#   '2018-04-26',
#   '2018-05-29',
#   '2018-07-20'],
#  '010950': ['2018-01-29', '2018-10-19'],
#  '000660': ['2018-01-02',
#   '2018-01-03',
#   '2018-01-04',
#   '2018-01-05',
#   '2018-01-08',
#   '2018-01-09',
#   '2018-01-10',
#   '2018-01-11',
#   '2018-01-12',
#   '2018-01-15',
#   '2018-01-16',
#   '2018-01-17',
#   '2018-01-18',
#   '2018-01-19',
#   '2018-01-22',
#   '2018-01-23',
#   '2018-01-24',
#   '2018-01-25',
#   '2018-01-26',
#   '2018-01-29',
#   '2018-01-30',
#   '2018-01-31',
#   '2018-02-01',
#   '2018-02-02',
#   '2018-02-05',
#   '2018-02-06',
#   '2018-02-07',
#   '2018-02-08',
#   '2018-02-09',
#   '2018-02-12',
#   '2018-02-13',
#   '2018-02-14',
#   '2018-02-19',
#   '2018-02-20',
#   '2018-02-21',
#   '2018-02-22',
#   '2018-02-23',
#   '2018-02-26',
#   '2018-02-27',
#   '2018-02-28',
#   '2018-03-02',
#   '2018-03-05',
#   '2018-03-06',
#   '2018-03-07',
#   '2018-03-08',
#   '2018-03-09',
#   '2018-03-12',
#   '2018-03-13',
#   '2018-03-14',
#   '2018-03-15',
#   '2018-03-16',
#   '2018-03-19',
#   '2018-03-20',
#   '2018-03-21',
#   '2018-03-22',
#   '2018-03-23',
#   '2018-03-26',
#   '2018-03-27',
#   '2018-03-28',
#   '2018-03-29',
#   '2018-03-30',
#   '2018-04-02',
#   '2018-04-03',
#   '2018-04-04',
#   '2018-04-05',
#   '2018-04-06',
#   '2018-04-09',
#   '2018-04-10',
#   '2018-04-11',
#   '2018-04-12',
#   '2018-04-13',
#   '2018-04-16',
#   '2018-04-17',
#   '2018-04-18',
#   '2018-04-19',
#   '2018-04-20',
#   '2018-04-23',
#   '2018-04-24',
#   '2018-04-25',
#   '2018-04-26',
#   '2018-04-27',
#   '2018-04-30',
#   '2018-05-02',
#   '2018-05-03',
#   '2018-05-04',
#   '2018-05-08',
#   '2018-05-09',
#   '2018-05-10',
#   '2018-05-11',
#   '2018-05-14',
#   '2018-05-15',
#   '2018-05-16',
#   '2018-05-17',
#   '2018-05-18',
#   '2018-05-21',
#   '2018-05-23',
#   '2018-05-24',
#   '2018-05-25',
#   '2018-05-28',
#   '2018-05-29',
#   '2018-05-30',
#   '2018-05-31',
#   '2018-06-01',
#   '2018-06-04',
#   '2018-06-05',
#   '2018-06-07',
#   '2018-06-08',
#   '2018-06-11',
#   '2018-06-12',
#   '2018-06-14',
#   '2018-06-15',
#   '2018-06-18',
#   '2018-06-19',
#   '2018-06-20',
#   '2018-06-21',
#   '2018-06-22',
#   '2018-06-25',
#   '2018-06-26',
#   '2018-06-27',
#   '2018-06-28',
#   '2018-06-29',
#   '2018-07-02',
#   '2018-07-03',
#   '2018-07-04',
#   '2018-07-05',
#   '2018-07-06',
#   '2018-07-09',
#   '2018-07-10',
#   '2018-07-11',
#   '2018-07-12',
#   '2018-07-13',
#   '2018-07-16',
#   '2018-07-17',
#   '2018-07-18',
#   '2018-07-19',
#   '2018-07-20',
#   '2018-07-23',
#   '2018-07-24',
#   '2018-07-25',
#   '2018-07-26',
#   '2018-07-27',
#   '2018-07-30',
#   '2018-07-31',
#   '2018-08-01',
#   '2018-08-02',
#   '2018-08-03',
#   '2018-08-06',
#   '2018-08-07',
#   '2018-08-08',
#   '2018-08-09',
#   '2018-08-10',
#   '2018-08-13',
#   '2018-08-14',
#   '2018-08-16',
#   '2018-08-17',
#   '2018-08-20',
#   '2018-08-21',
#   '2018-08-22',
#   '2018-08-23',
#   '2018-08-24',
#   '2018-08-27',
#   '2018-08-28',
#   '2018-08-29',
#   '2018-08-30',
#   '2018-08-31',
#   '2018-09-03',
#   '2018-09-04',
#   '2018-09-05',
#   '2018-09-06',
#   '2018-09-07',
#   '2018-09-10',
#   '2018-09-11',
#   '2018-09-12',
#   '2018-09-13',
#   '2018-09-14',
#   '2018-09-17',
#   '2018-09-18',
#   '2018-09-19',
#   '2018-09-20',
#   '2018-09-21',
#   '2018-09-27',
#   '2018-09-28',
#   '2018-10-01',
#   '2018-10-02',
#   '2018-10-04',
#   '2018-10-05',
#   '2018-10-08',
#   '2018-10-10',
#   '2018-10-11',
#   '2018-10-12',
#   '2018-10-15',
#   '2018-10-16',
#   '2018-10-17',
#   '2018-10-18',
#   '2018-10-19',
#   '2018-10-22',
#   '2018-10-23',
#   '2018-10-24',
#   '2018-10-25',
#   '2018-10-26',
#   '2018-10-29',
#   '2018-10-30',
#   '2018-10-31',
#   '2018-11-01',
#   '2018-11-02',
#   '2018-11-05',
#   '2018-11-06',
#   '2018-11-07',
#   '2018-11-08',
#   '2018-11-09',
#   '2018-11-12',
#   '2018-11-13',
#   '2018-11-14',
#   '2018-11-15',
#   '2018-11-16',
#   '2018-11-19',
#   '2018-11-20',
#   '2018-11-21',
#   '2018-11-22',
#   '2018-11-23',
#   '2018-11-26',
#   '2018-11-27',
#   '2018-11-28',
#   '2018-11-29',
#   '2018-11-30',
#   '2018-12-03',
#   '2018-12-04',
#   '2018-12-05',
#   '2018-12-06',
#   '2018-12-07',
#   '2018-12-10',
#   '2018-12-11',
#   '2018-12-12',
#   '2018-12-13',
#   '2018-12-14',
#   '2018-12-17',
#   '2018-12-18',
#   '2018-12-19',
#   '2018-12-20',
#   '2018-12-21',
#   '2018-12-24',
#   '2018-12-26',
#   '2018-12-27'],
#  '000270': ['2018-04-03'],
#  '025860': ['2018-05-02'],
#  '008420': ['2018-06-19', '2018-06-20'],
#  '009150': ['2018-01-05',
#   '2018-01-08',
#   '2018-01-10',
#   '2018-01-19',
#   '2018-01-22',
#   '2018-01-29',
#   '2018-01-31',
#   '2018-02-01',
#   '2018-03-19',
#   '2018-03-22',
#   '2018-03-23',
#   '2018-03-26',
#   '2018-03-27',
#   '2018-04-10',
#   '2018-04-12',
#   '2018-04-13',
#   '2018-04-16',
#   '2018-04-17',
#   '2018-04-18',
#   '2018-04-19',
#   '2018-04-20',
#   '2018-04-24',
#   '2018-04-25',
#   '2018-04-26',
#   '2018-04-27',
#   '2018-05-03',
#   '2018-05-04',
#   '2018-05-09',
#   '2018-05-17',
#   '2018-05-21',
#   '2018-05-23',
#   '2018-05-31',
#   '2018-06-01',
#   '2018-06-07',
#   '2018-06-15',
#   '2018-06-20',
#   '2018-06-21',
#   '2018-06-22',
#   '2018-06-26',
#   '2018-07-03',
#   '2018-07-04',
#   '2018-07-05',
#   '2018-07-06',
#   '2018-07-09',
#   '2018-07-13',
#   '2018-07-18',
#   '2018-07-20',
#   '2018-07-23',
#   '2018-07-24',
#   '2018-07-25',
#   '2018-07-26',
#   '2018-07-30',
#   '2018-07-31',
#   '2018-08-02',
#   '2018-08-06',
#   '2018-08-09',
#   '2018-08-10',
#   '2018-08-13',
#   '2018-08-14',
#   '2018-08-20',
#   '2018-08-21',
#   '2018-08-22',
#   '2018-08-24',
#   '2018-08-27',
#   '2018-08-28',
#   '2018-08-29',
#   '2018-09-07',
#   '2018-09-10',
#   '2018-09-11',
#   '2018-09-12',
#   '2018-09-13',
#   '2018-09-14',
#   '2018-09-20',
#   '2018-09-21',
#   '2018-09-27',
#   '2018-09-28',
#   '2018-10-01',
#   '2018-10-02',
#   '2018-10-04',
#   '2018-10-05',
#   '2018-10-08',
#   '2018-10-10',
#   '2018-10-11',
#   '2018-10-12',
#   '2018-10-15',
#   '2018-10-16',
#   '2018-10-17',
#   '2018-10-18',
#   '2018-10-19',
#   '2018-10-22',
#   '2018-10-23',
#   '2018-10-24',
#   '2018-10-25',
#   '2018-10-26',
#   '2018-10-29',
#   '2018-10-30',
#   '2018-10-31',
#   '2018-11-01',
#   '2018-11-02',
#   '2018-11-05',
#   '2018-11-06',
#   '2018-11-07',
#   '2018-11-08',
#   '2018-11-09',
#   '2018-11-12',
#   '2018-11-13',
#   '2018-11-14',
#   '2018-11-15',
#   '2018-11-16',
#   '2018-11-19',
#   '2018-11-20',
#   '2018-11-21',
#   '2018-11-22',
#   '2018-11-23',
#   '2018-11-26',
#   '2018-11-27',
#   '2018-11-28',
#   '2018-11-29',
#   '2018-11-30',
#   '2018-12-03',
#   '2018-12-04',
#   '2018-12-05',
#   '2018-12-06',
#   '2018-12-10',
#   '2018-12-11',
#   '2018-12-12',
#   '2018-12-13',
#   '2018-12-14',
#   '2018-12-17',
#   '2018-12-18',
#   '2018-12-19',
#   '2018-12-20',
#   '2018-12-21',
#   '2018-12-26',
#   '2018-12-27'],
#  '007540': ['2018-10-11'],
#  '009270': ['2018-03-07', '2018-04-23'],
#  '000100': ['2018-11-05',
#   '2018-11-06',
#   '2018-11-07',
#   '2018-11-08',
#   '2018-11-19'],
#  '084680': ['2018-12-06'],
#  '010820': ['2018-04-25',
#   '2018-04-26',
#   '2018-04-27',
#   '2018-04-30',
#   '2018-06-05',
#   '2018-06-07',
#   '2018-06-08',
#   '2018-06-11',
#   '2018-06-12',
#   '2018-06-14'],
#  '006390': ['2018-05-17',
#   '2018-05-18',
#   '2018-05-29',
#   '2018-06-11',
#   '2018-06-12',
#   '2018-06-29'],
#  '003010': ['2018-04-24', '2018-04-26', '2018-05-04', '2018-09-18'],
#  '032640': ['2018-08-31', '2018-11-07', '2018-11-30'],
#  '006340': ['2018-05-14', '2018-05-17', '2018-05-23'],
#  '002210': ['2018-01-19',
#   '2018-01-22',
#   '2018-01-30',
#   '2018-01-31',
#   '2018-02-09',
#   '2018-02-12',
#   '2018-02-20',
#   '2018-03-19',
#   '2018-03-20',
#   '2018-03-21',
#   '2018-03-22',
#   '2018-03-23',
#   '2018-03-30',
#   '2018-07-20',
#   '2018-08-23',
#   '2018-08-24',
#   '2018-08-27',
#   '2018-08-28',
#   '2018-08-30',
#   '2018-09-05',
#   '2018-09-06',
#   '2018-09-07',
#   '2018-09-12',
#   '2018-09-19',
#   '2018-09-28',
#   '2018-10-01',
#   '2018-10-02',
#   '2018-10-04',
#   '2018-10-05',
#   '2018-11-05',
#   '2018-12-18'],
#  '010140': ['2018-01-10',
#   '2018-01-25',
#   '2018-01-29',
#   '2018-03-06',
#   '2018-03-07',
#   '2018-05-08'],
#  '091090': ['2018-03-15', '2018-03-19'],
#  '001780': ['2018-05-10', '2018-05-11'],
#  '004720': ['2018-02-21'],
#  '090080': ['2018-06-27', '2018-07-02'],
#  '025750': ['2018-05-08', '2018-09-06'],
#  '012330': ['2018-01-04',
#   '2018-01-26',
#   '2018-02-02',
#   '2018-02-08',
#   '2018-02-13',
#   '2018-03-27',
#   '2018-03-28',
#   '2018-03-29',
#   '2018-03-30',
#   '2018-04-02',
#   '2018-04-03',
#   '2018-04-04',
#   '2018-05-23',
#   '2018-05-31',
#   '2018-06-15',
#   '2018-08-08',
#   '2018-11-22',
#   '2018-12-13'],
#  '081660': ['2018-11-30'],
#  '026890': ['2018-10-15',
#   '2018-10-16',
#   '2018-10-19',
#   '2018-10-23',
#   '2018-10-31',
#   '2018-11-02',
#   '2018-11-05',
#   '2018-11-06',
#   '2018-11-07',
#   '2018-11-08',
#   '2018-11-09',
#   '2018-11-13',
#   '2018-11-16'],
#  '004170': ['2018-01-26', '2018-06-25'],
#  '008700': ['2018-01-09',
#   '2018-01-10',
#   '2018-01-11',
#   '2018-01-25',
#   '2018-01-26',
#   '2018-02-01',
#   '2018-02-06',
#   '2018-02-07',
#   '2018-02-09',
#   '2018-02-13',
#   '2018-08-02',
#   '2018-08-06',
#   '2018-08-08'],
#  '002630': ['2018-09-28', '2018-10-01'],
#  '074610': ['2018-01-09', '2018-04-02', '2018-04-17', '2018-04-18'],
#  '007110': ['2018-04-23'],
#  '020150': ['2018-08-31', '2018-11-23'],
#  '021240': ['2018-07-18', '2018-09-19', '2018-10-30'],
#  '005690': ['2018-03-14',
#   '2018-03-15',
#   '2018-03-19',
#   '2018-03-21',
#   '2018-03-22',
#   '2018-03-28',
#   '2018-03-29',
#   '2018-04-05',
#   '2018-04-06',
#   '2018-04-09',
#   '2018-04-10',
#   '2018-04-11',
#   '2018-04-12',
#   '2018-04-13',
#   '2018-04-18',
#   '2018-04-19',
#   '2018-04-20',
#   '2018-04-25',
#   '2018-04-30',
#   '2018-05-02',
#   '2018-05-09',
#   '2018-05-10',
#   '2018-05-11',
#   '2018-05-16',
#   '2018-05-17'],
#  '128940': ['2018-01-12', '2018-02-06', '2018-02-19', '2018-04-10'],
#  '004310': ['2018-01-11', '2018-02-12', '2018-02-13', '2018-04-04'],
#  '057050': ['2018-04-05'],
#  '096760': ['2018-04-11'],
#  '033180': ['2018-02-28',
#   '2018-03-21',
#   '2018-03-22',
#   '2018-03-29',
#   '2018-03-30',
#   '2018-04-02',
#   '2018-04-03',
#   '2018-04-04',
#   '2018-04-10',
#   '2018-04-11',
#   '2018-04-12',
#   '2018-04-13',
#   '2018-04-16',
#   '2018-04-17',
#   '2018-04-18',
#   '2018-04-19',
#   '2018-04-20',
#   '2018-04-23',
#   '2018-04-24',
#   '2018-04-25',
#   '2018-05-02',
#   '2018-05-03',
#   '2018-06-01',
#   '2018-06-04',
#   '2018-06-07',
#   '2018-06-08',
#   '2018-06-12',
#   '2018-06-15',
#   '2018-07-04',
#   '2018-07-05',
#   '2018-07-23',
#   '2018-07-24',
#   '2018-08-20',
#   '2018-08-29',
#   '2018-09-04',
#   '2018-09-06',
#   '2018-09-07',
#   '2018-09-12',
#   '2018-09-14'],
#  '004540': ['2018-05-21', '2018-05-23'],
#  '003580': ['2018-07-05'],
#  '025560': ['2018-01-02',
#   '2018-01-03',
#   '2018-01-04',
#   '2018-01-05',
#   '2018-01-08',
#   '2018-01-09',
#   '2018-01-10',
#   '2018-01-11',
#   '2018-01-12',
#   '2018-01-15',
#   '2018-01-16',
#   '2018-01-17',
#   '2018-01-18',
#   '2018-01-19',
#   '2018-01-22',
#   '2018-01-23',
#   '2018-01-24',
#   '2018-01-25',
#   '2018-01-26',
#   '2018-01-29',
#   '2018-01-30',
#   '2018-01-31',
#   '2018-02-01',
#   '2018-02-02',
#   '2018-02-05',
#   '2018-02-06',
#   '2018-02-07',
#   '2018-02-08',
#   '2018-02-09',
#   '2018-02-12',
#   '2018-02-13',
#   '2018-02-14',
#   '2018-02-19',
#   '2018-02-20',
#   '2018-02-21',
#   '2018-02-22',
#   '2018-02-23',
#   '2018-02-26',
#   '2018-02-27',
#   '2018-02-28',
#   '2018-03-02',
#   '2018-03-05',
#   '2018-03-06',
#   '2018-03-07',
#   '2018-03-08',
#   '2018-03-09',
#   '2018-03-12',
#   '2018-03-13',
#   '2018-03-14',
#   '2018-03-15',
#   '2018-03-16',
#   '2018-03-19',
#   '2018-03-20',
#   '2018-03-21',
#   '2018-03-22',
#   '2018-03-23',
#   '2018-03-26',
#   '2018-03-27',
#   '2018-03-28',
#   '2018-03-29',
#   '2018-03-30',
#   '2018-04-02',
#   '2018-04-03',
#   '2018-04-04',
#   '2018-04-05',
#   '2018-04-06',
#   '2018-04-09',
#   '2018-04-10',
#   '2018-04-11',
#   '2018-04-12',
#   '2018-04-13',
#   '2018-04-16',
#   '2018-04-17',
#   '2018-04-18',
#   '2018-04-19',
#   '2018-04-20',
#   '2018-04-23',
#   '2018-04-24',
#   '2018-04-25',
#   '2018-04-26',
#   '2018-04-27',
#   '2018-04-30',
#   '2018-05-02',
#   '2018-05-03',
#   '2018-05-04',
#   '2018-05-08',
#   '2018-05-09',
#   '2018-05-10',
#   '2018-05-11',
#   '2018-05-14',
#   '2018-05-15',
#   '2018-05-16',
#   '2018-05-17',
#   '2018-05-18',
#   '2018-05-21',
#   '2018-05-23',
#   '2018-05-24',
#   '2018-05-25',
#   '2018-05-28',
#   '2018-05-29',
#   '2018-05-30',
#   '2018-05-31',
#   '2018-06-01',
#   '2018-06-04',
#   '2018-06-05',
#   '2018-06-07',
#   '2018-06-08',
#   '2018-06-11',
#   '2018-06-12',
#   '2018-06-14',
#   '2018-06-15',
#   '2018-06-18',
#   '2018-06-19',
#   '2018-06-21',
#   '2018-06-22',
#   '2018-06-25',
#   '2018-06-26',
#   '2018-06-27',
#   '2018-06-28',
#   '2018-06-29',
#   '2018-07-02',
#   '2018-07-03',
#   '2018-07-04',
#   '2018-07-05',
#   '2018-07-06',
#   '2018-07-09',
#   '2018-07-10',
#   '2018-07-11',
#   '2018-07-12',
#   '2018-07-13',
#   '2018-07-16',
#   '2018-07-17',
#   '2018-07-18',
#   '2018-07-19',
#   '2018-07-20',
#   '2018-07-23',
#   '2018-07-24',
#   '2018-07-25',
#   '2018-07-26',
#   '2018-07-27',
#   '2018-07-30',
#   '2018-07-31',
#   '2018-08-01',
#   '2018-08-02',
#   '2018-08-03',
#   '2018-08-06',
#   '2018-08-07',
#   '2018-08-08',
#   '2018-08-09',
#   '2018-08-10',
#   '2018-08-13',
#   '2018-08-14',
#   '2018-08-16',
#   '2018-08-17',
#   '2018-08-20',
#   '2018-08-21',
#   '2018-08-22',
#   '2018-08-23',
#   '2018-08-27',
#   '2018-08-28',
#   '2018-08-29',
#   '2018-08-30',
#   '2018-08-31',
#   '2018-09-03',
#   '2018-09-04',
#   '2018-09-05',
#   '2018-09-06',
#   '2018-09-07',
#   '2018-09-10',
#   '2018-09-11',
#   '2018-09-12',
#   '2018-09-13',
#   '2018-09-14',
#   '2018-09-17',
#   '2018-09-19',
#   '2018-09-20',
#   '2018-09-21',
#   '2018-09-28',
#   '2018-10-01',
#   '2018-10-02',
#   '2018-10-04',
#   '2018-10-05',
#   '2018-10-08',
#   '2018-10-10',
#   '2018-10-11',
#   '2018-10-12',
#   '2018-10-15',
#   '2018-10-19',
#   '2018-10-23',
#   '2018-10-24',
#   '2018-10-25',
#   '2018-10-26',
#   '2018-10-29',
#   '2018-10-30',
#   '2018-10-31',
#   '2018-11-01',
#   '2018-11-02',
#   '2018-11-05',
#   '2018-11-08',
#   '2018-11-09',
#   '2018-11-12',
#   '2018-11-13',
#   '2018-11-14',
#   '2018-11-15',
#   '2018-11-29',
#   '2018-12-04',
#   '2018-12-26'],
#  '000890': ['2018-12-05',
#   '2018-12-14',
#   '2018-12-17',
#   '2018-12-27',
#   '2018-12-28'],
#  '030790': ['2018-01-03',
#   '2018-01-18',
#   '2018-01-23',
#   '2018-01-24',
#   '2018-01-25',
#   '2018-01-26',
#   '2018-01-29',
#   '2018-01-30',
#   '2018-01-31',
#   '2018-02-01',
#   '2018-02-02',
#   '2018-02-05',
#   '2018-02-06',
#   '2018-02-07',
#   '2018-02-08',
#   '2018-02-09',
#   '2018-02-12',
#   '2018-02-13',
#   '2018-02-19',
#   '2018-02-26',
#   '2018-02-27',
#   '2018-03-02',
#   '2018-03-05',
#   '2018-03-06',
#   '2018-03-07',
#   '2018-03-08',
#   '2018-03-09',
#   '2018-03-12',
#   '2018-03-13',
#   '2018-03-14',
#   '2018-03-15',
#   '2018-03-16',
#   '2018-03-19',
#   '2018-03-20',
#   '2018-03-21',
#   '2018-03-23',
#   '2018-03-27',
#   '2018-03-28',
#   '2018-03-29',
#   '2018-03-30',
#   '2018-04-02',
#   '2018-04-03',
#   '2018-04-05',
#   '2018-04-06',
#   '2018-04-09',
#   '2018-04-10',
#   '2018-04-11',
#   '2018-04-12',
#   '2018-04-13',
#   '2018-04-16',
#   '2018-04-17',
#   '2018-04-18',
#   '2018-04-23',
#   '2018-04-24',
#   '2018-04-25',
#   '2018-04-26',
#   '2018-04-27',
#   '2018-04-30',
#   '2018-05-02',
#   '2018-05-04',
#   '2018-05-08',
#   '2018-05-09',
#   '2018-05-16',
#   '2018-05-17',
#   '2018-05-18',
#   '2018-05-21',
#   '2018-05-23',
#   '2018-05-24',
#   '2018-05-25',
#   '2018-05-28',
#   '2018-05-29',
#   '2018-05-30',
#   '2018-05-31',
#   '2018-06-01',
#   '2018-06-04',
#   '2018-06-05',
#   '2018-06-11',
#   '2018-06-14',
#   '2018-06-15',
#   '2018-06-18',
#   '2018-06-19',
#   '2018-06-25',
#   '2018-06-27',
#   '2018-06-28',
#   '2018-06-29',
#   '2018-07-06',
#   '2018-07-10',
#   '2018-07-11',
#   '2018-07-12',
#   '2018-07-13',
#   '2018-07-18',
#   '2018-07-19',
#   '2018-07-26',
#   '2018-07-27',
#   '2018-07-31',
#   '2018-08-17',
#   '2018-08-20',
#   '2018-09-04',
#   '2018-09-05',
#   '2018-09-12',
#   '2018-09-13',
#   '2018-09-14',
#   '2018-09-17',
#   '2018-09-18',
#   '2018-09-19',
#   '2018-09-20',
#   '2018-10-01',
#   '2018-10-02',
#   '2018-10-22',
#   '2018-10-30',
#   '2018-11-07',
#   '2018-11-21',
#   '2018-12-20'],
#  '028260': ['2018-01-09',
#   '2018-01-29',
#   '2018-01-31',
#   '2018-02-05',
#   '2018-02-06',
#   '2018-03-29',
#   '2018-03-30',
#   '2018-04-10',
#   '2018-04-11',
#   '2018-04-12',
#   '2018-04-16',
#   '2018-04-26',
#   '2018-05-02',
#   '2018-05-04',
#   '2018-09-20',
#   '2018-09-21',
#   '2018-09-27',
#   '2018-09-28',
#   '2018-10-02',
#   '2018-10-11',
#   '2018-12-13'],
#  '005930': ['2018-05-04',
#   '2018-05-08',
#   '2018-05-09',
#   '2018-05-10',
#   '2018-05-11',
#   '2018-05-14',
#   '2018-05-15',
#   '2018-05-16',
#   '2018-05-17',
#   '2018-05-18',
#   '2018-05-21',
#   '2018-05-23',
#   '2018-05-24',
#   '2018-05-25',
#   '2018-05-28',
#   '2018-05-29',
#   '2018-05-30',
#   '2018-05-31',
#   '2018-06-01',
#   '2018-06-04',
#   '2018-06-05',
#   '2018-06-07',
#   '2018-06-08',
#   '2018-06-11',
#   '2018-06-12',
#   '2018-06-14',
#   '2018-06-15',
#   '2018-06-18',
#   '2018-06-19',
#   '2018-06-20',
#   '2018-06-21',
#   '2018-06-22',
#   '2018-06-25',
#   '2018-06-26',
#   '2018-06-27',
#   '2018-06-28',
#   '2018-06-29',
#   '2018-07-02',
#   '2018-07-03',
#   '2018-07-04',
#   '2018-07-05',
#   '2018-07-06',
#   '2018-07-09',
#   '2018-07-10',
#   '2018-07-11',
#   '2018-07-12',
#   '2018-07-13',
#   '2018-07-16',
#   '2018-07-17',
#   '2018-07-18',
#   '2018-07-19',
#   '2018-07-20',
#   '2018-07-23',
#   '2018-07-24',
#   '2018-07-25',
#   '2018-07-26',
#   '2018-07-27',
#   '2018-07-30',
#   '2018-07-31',
#   '2018-08-01',
#   '2018-08-02',
#   '2018-08-03',
#   '2018-08-06',
#   '2018-08-07',
#   '2018-08-08',
#   '2018-08-09',
#   '2018-08-10',
#   '2018-08-13',
#   '2018-08-14',
#   '2018-08-16',
#   '2018-08-17',
#   '2018-08-20',
#   '2018-08-21',
#   '2018-08-22',
#   '2018-08-23',
#   '2018-08-24',
#   '2018-08-27',
#   '2018-08-28',
#   '2018-08-29',
#   '2018-08-30',
#   '2018-08-31',
#   '2018-09-03',
#   '2018-09-04',
#   '2018-09-05',
#   '2018-09-06',
#   '2018-09-07',
#   '2018-09-10',
#   '2018-09-11',
#   '2018-09-12',
#   '2018-09-13',
#   '2018-09-14',
#   '2018-09-17',
#   '2018-09-18',
#   '2018-09-19',
#   '2018-09-20',
#   '2018-09-21',
#   '2018-09-27',
#   '2018-09-28',
#   '2018-10-01',
#   '2018-10-02',
#   '2018-10-04',
#   '2018-10-05',
#   '2018-10-08',
#   '2018-10-10',
#   '2018-10-11',
#   '2018-10-12',
#   '2018-10-15',
#   '2018-10-16',
#   '2018-10-17',
#   '2018-10-18',
#   '2018-10-19',
#   '2018-10-22',
#   '2018-10-23',
#   '2018-10-24',
#   '2018-10-25',
#   '2018-10-26',
#   '2018-10-29',
#   '2018-10-30',
#   '2018-10-31',
#   '2018-11-01',
#   '2018-11-02',
#   '2018-11-05',
#   '2018-11-06',
#   '2018-11-07',
#   '2018-11-08',
#   '2018-11-09',
#   '2018-11-12',
#   '2018-11-13',
#   '2018-11-14',
#   '2018-11-15',
#   '2018-11-16',
#   '2018-11-19',
#   '2018-11-20',
#   '2018-11-21',
#   '2018-11-22',
#   '2018-11-23',
#   '2018-11-26',
#   '2018-11-27',
#   '2018-11-28',
#   '2018-11-29',
#   '2018-11-30',
#   '2018-12-03',
#   '2018-12-04',
#   '2018-12-05',
#   '2018-12-06',
#   '2018-12-07',
#   '2018-12-10',
#   '2018-12-11',
#   '2018-12-12',
#   '2018-12-13',
#   '2018-12-14',
#   '2018-12-17',
#   '2018-12-18',
#   '2018-12-19',
#   '2018-12-20',
#   '2018-12-21',
#   '2018-12-24',
#   '2018-12-26',
#   '2018-12-27',
#   '2018-12-28'],
#  '001820': ['2018-01-16', '2018-07-09', '2018-08-14', '2018-08-21'],
#  '004980': ['2018-05-17'],
#  '010050': ['2018-05-21', '2018-05-23', '2018-05-24'],
#  '086790': ['2018-04-23', '2018-10-25'],
#  '180640': ['2018-11-14', '2018-11-16', '2018-11-19', '2018-11-20'],
#  '005440': ['2018-04-05'],
#  '064350': ['2018-04-27',
#   '2018-04-30',
#   '2018-05-02',
#   '2018-05-03',
#   '2018-05-04',
#   '2018-05-08',
#   '2018-05-09',
#   '2018-05-10',
#   '2018-05-14',
#   '2018-05-15',
#   '2018-05-16',
#   '2018-05-17',
#   '2018-05-18',
#   '2018-05-21',
#   '2018-05-23',
#   '2018-05-24',
#   '2018-05-25',
#   '2018-05-28',
#   '2018-05-29',
#   '2018-05-30',
#   '2018-05-31',
#   '2018-06-01',
#   '2018-06-04',
#   '2018-06-05',
#   '2018-06-07',
#   '2018-06-08',
#   '2018-06-11',
#   '2018-06-12',
#   '2018-06-14',
#   '2018-06-15',
#   '2018-06-18',
#   '2018-06-19',
#   '2018-06-20',
#   '2018-06-22',
#   '2018-06-25',
#   '2018-06-26',
#   '2018-06-27',
#   '2018-06-28',
#   '2018-06-29',
#   '2018-07-11',
#   '2018-07-24',
#   '2018-07-25',
#   '2018-07-26',
#   '2018-07-30',
#   '2018-07-31',
#   '2018-08-10',
#   '2018-08-13',
#   '2018-08-16',
#   '2018-08-17',
#   '2018-08-20',
#   '2018-08-21',
#   '2018-08-27',
#   '2018-09-06',
#   '2018-09-07',
#   '2018-09-10',
#   '2018-09-11',
#   '2018-09-17',
#   '2018-09-18',
#   '2018-09-19',
#   '2018-09-20',
#   '2018-09-21',
#   '2018-09-27',
#   '2018-10-04',
#   '2018-10-10',
#   '2018-10-30',
#   '2018-11-23',
#   '2018-11-26',
#   '2018-12-03'],
#  '005380': ['2018-01-02',
#   '2018-01-04',
#   '2018-01-10',
#   '2018-01-19',
#   '2018-01-23',
#   '2018-01-24',
#   '2018-01-25',
#   '2018-01-26',
#   '2018-01-31',
#   '2018-02-02',
#   '2018-02-05',
#   '2018-02-06',
#   '2018-02-08',
#   '2018-02-09',
#   '2018-03-19',
#   '2018-03-27',
#   '2018-03-28',
#   '2018-03-29',
#   '2018-04-03',
#   '2018-04-04',
#   '2018-04-17',
#   '2018-04-24',
#   '2018-04-26',
#   '2018-04-27',
#   '2018-05-10',
#   '2018-05-23',
#   '2018-05-24',
#   '2018-05-31',
#   '2018-06-04',
#   '2018-06-14',
#   '2018-06-15',
#   '2018-06-19',
#   '2018-06-27',
#   '2018-06-28',
#   '2018-07-05',
#   '2018-08-08',
#   '2018-09-05',
#   '2018-09-06',
#   '2018-09-07',
#   '2018-10-25',
#   '2018-11-20',
#   '2018-11-22',
#   '2018-11-27',
#   '2018-11-30',
#   '2018-12-12',
#   '2018-12-13',
#   '2018-12-18',
#   '2018-12-19'],
#  '011760': ['2018-05-15',
#   '2018-05-17',
#   '2018-06-07',
#   '2018-06-11',
#   '2018-06-12']}

# %% [markdown]
# # x 저장

# %%
# x_df.to_csv('capstone_x.csv', index = False)
# y_df.to_csv('capstone_y.csv', index = False)
pd.read_csv('capstone_x.csv')
# Out:
#          Code        Date   Open   High    Low  Close    Volume  \
# 0       50120  2018-01-02  10250  12050  10150  11800  26086769
# 1       50120  2018-01-03  11950  12450  10900  11750  20460474
# 2       50120  2018-01-04  11850  14150  11600  12600  60663854
# 3       50120  2018-01-05  12800  13200  12000  12200  13935258
# 4       50120  2018-01-08  12450  13400  12350  12850  16471707
# ...       ...         ...    ...    ...    ...    ...       ...
# 380584    540  2018-12-21   4480   4480   4330   4480    109164
# 380585    540  2018-12-24   4480   4530   4440   4520     36973
# 380586    540  2018-12-26   4515   4515   4275   4470     28747
# 380587    540  2018-12-27   4475   4500   4410   4470     20617
# 380588    540  2018-12-28   4500   4825   4440   4705     60012
#
#         Trading_Value    Change      MA5  ...      SRSI      TSI       UO  \
# 0        307823874200  0.145631  10108.0  ...  0.617452  22.3595  45.6450
# 1        240410569500 -0.004237  10538.0  ...  0.606881  24.6104  44.5857
# 2        764364560400  0.072340  11232.0  ...  0.691669  27.8890  46.0102
# 3        170010147600 -0.031746  11730.0  ...  0.605418  28.9426  46.8657
# 4        211661434950  0.053279  12240.0  ...  0.670468  30.8389  48.7672
# ...               ...       ...      ...  ...       ...      ...      ...
# 380584      489054720  0.000000   4573.0  ...  0.000000 -48.1839  40.9134
# 380585      167117960  0.008929   4534.0  ...  0.250801 -48.6931  47.1329
# 380586      128499090 -0.011062   4512.0  ...  0.177769 -49.7125  54.1570
# 380587       92157990  0.000000   4484.0  ...  0.291459 -50.5188  54.6350
# 380588      282356460  0.052573   4529.0  ...  1.000000 -42.8563  62.2204
#
#              SR       WR        AO      KAMA       ROC      PPO       PVO
# 0       73.6842 -26.3158  1259.470   9897.76  44.78530  6.24021  42.05600
# 1       72.7096 -27.2904  1435.350  10067.00  44.17180  7.16213  36.42410
# 2       74.7145 -25.2855  1988.650  10221.40  53.09840  8.40391  42.40620
# 3       67.9276 -32.0724  2473.210  10308.60  51.17720  8.92074  34.04080
# 4       78.6184 -21.3816  2793.380  10359.80  26.60100  9.65555  27.63640
# ...         ...      ...       ...       ...       ...      ...       ...
# 380584  21.4286 -78.5714  -363.397   4592.44 -10.31030 -3.14961   2.96624
# 380585  27.1429 -72.8571  -394.015   4580.40  -8.87097 -3.21322   3.55599
# 380586  27.2727 -72.7273  -422.632   4560.38  -7.83505 -3.31474   2.02404
# 380587  28.4672 -71.5328  -430.515   4538.92  -6.58307 -3.35971  -1.25023
# 380588  73.5043 -26.4957  -402.265   4540.78  -1.36268 -2.95350   5.69357
#
# [380589 rows x 58 columns]

# %%
# 방법2) 시간 반으로 줄었음.

# %%time

dday_alldf = pd.DataFrame()

# need_date가 아닌 cd_dt_dic에서 고르기
for k,(key, val) in tqdm(enumerate(cd_dt_dic.items())):
#     key인 동안에
    for i in val:
        if np.where(x_df[x_df['Code']==key]['Date'].values == i)[0][0] >= 9 :
            idx = x_df[x_df['Code']==key][x_df['Date']==i].index
            
            #dday_df : 한 date에 대한 data 한 줄
            dday_df = pd.DataFrame([x_df.iloc[:,0:2].loc[idx.values[0]]])
            dday_df.rename(index = {idx.values[0] : i}, inplace = True) # dday_df의 code와 같은 code인 df(x)중에서 고르기

            for j in range(9, -1, -1):

                tmp = x_df.iloc[idx-j].iloc[:,2:]
                tmp.columns = [f'D-{j}_{ori_col}' for ori_col in x_df.iloc[:,2:].columns]
                tmp = tmp.rename(index = {idx.values[0]-j : i})
        
                dday_df = pd.concat([dday_df, tmp], axis = 1) # dday_df 옆으로 concat
            
            # dday_df 옆에 같은 idx의 y 붙여주기
            dday_df = pd.concat([dday_df, y_df.iloc[idx]['Next_Change'].rename(index = {idx.values[0]:i})], axis = 1)
            
            # dday_alldf: data 아래로 이어붙이기
            dday_alldf = pd.concat([dday_alldf, dday_df])
# Out:
# 0it [00:00, ?it/s]
# <timed exec>:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# CPU times: user 8min 51s, sys: 91.6 ms, total: 8min 51s
# Wall time: 8min 51s

# %%
# # 방법3) 저장한 x를 with open에 돌리기 - 실패
# f = open('capstone_x.csv')
# lines = f.readlines()
# for i,line in tqdm(enumerate(lines)):
#     line = line.strip()
#     lst = np.array(line.split(','))
    
#     if i == 0 :
#         lst
#         cd_idx = np.where(lst == 'Code')[0][0] # code 열 idx
#         dt_idx = np.where(lst == 'Date')[0][0] # date 열 idx
#         cd_idx
#         dt_idx
#     elif i <= 3 :
# #         lst
#         for k,(key, val) in tqdm(enumerate(cd_dt_dic.items())):
#             for i in val:
#                 if lst[cd_idx]==key and lst # 아... x 자체의 idx를 이용하지 못함...
# #                 if np.where(x_df[x_df['Code']==key]['Date'].values == i)[0][0] >= 9 :
#                 break
            
#     else:
#         break

# %%
dday_alldf
# Out:
#               Code        Date D-9_Open D-9_High D-9_Low D-9_Close D-9_Volume  \
# 2018-01-15  050120  2018-01-15    10250    12050   10150     11800   26086769
# 2018-01-16  050120  2018-01-16    11950    12450   10900     11750   20460474
# 2018-01-17  050120  2018-01-17    11850    14150   11600     12600   60663854
# 2018-01-18  050120  2018-01-18    12800    13200   12000     12200   13935258
# 2018-01-19  050120  2018-01-19    12450    13400   12350     12850   16471707
# ...            ...         ...      ...      ...     ...       ...        ...
# 2018-05-15  011760  2018-05-15    21400    24100   20800     22400    1488904
# 2018-05-17  011760  2018-05-17    23500    23850   21950     22350     489326
# 2018-06-07  011760  2018-06-07    41650    41900   37000     38800    1305256
# 2018-06-11  011760  2018-06-11    40500    41300   40050     41300     712521
# 2018-06-12  011760  2018-06-12    42650    44650   39500     40700    2115221
#
#            D-9_Trading_Value   D-9_Change D-9_MA5  ...  D-0_TSI   D-0_UO  \
# 2018-01-15      307823874200     0.145631   10108  ...  29.3225  45.3787
# 2018-01-16      240410569500  -0.00423729   10538  ...  28.0689  45.6406
# 2018-01-17      764364560400    0.0723404   11232  ...  22.3139  41.0354
# 2018-01-18      170010147600    -0.031746   11730  ...  18.8794  41.3833
# 2018-01-19      211661434950    0.0532787   12240  ...  16.5383  33.5502
# ...                      ...          ...     ...  ...      ...      ...
# 2018-05-15       33351449600    0.0953545   20830  ...  56.6722  68.0251
# 2018-05-17       10936436100   -0.0648536   22040  ...  54.5403  64.0099
# 2018-06-07       50643932800   -0.0582524   39190  ...  29.5457  49.8274
# 2018-06-11       29427117300     0.298742   38620  ...  31.8637  53.8917
# 2018-06-12       86089494700   -0.0145278   38760  ...    32.42   52.716
#
#              D-0_SR    D-0_WR              D-0_AO D-0_KAMA  D-0_ROC  D-0_PPO  \
# 2018-01-15  63.9228  -36.0772             3645.88  11858.8  68.6747  12.3246
# 2018-01-16   53.252   -46.748             3980.74  11947.6  47.7858  12.2902
# 2018-01-17   25.813   -74.187             3687.65  11946.2  13.1068  10.4433
# 2018-01-18  28.8725  -71.1275             2987.65  11947.9  3.38983  9.22399
# 2018-01-19       25       -75             2637.35  11949.9  5.10638  8.26069
# ...             ...       ...                 ...      ...      ...      ...
# 2018-05-15  84.6369  -15.3631             6866.91  27722.5  74.9373  13.0112
# 2018-05-17  85.1942  -14.8058  10338.970588235294  29517.6  83.1296  15.4888
# 2018-06-07  70.6329  -29.3671             10088.1  36598.8  11.8182   13.029
# 2018-06-11  95.8333  -4.16667             10979.7  39093.7  20.8738  13.9068
# 2018-06-12   75.502   -24.498             12323.8  39605.8  23.4536  14.1011
#
#             D-0_PVO  Next_Change
# 2018-01-15   38.852   -0.0681818
# 2018-01-16  30.6275    -0.188153
# 2018-01-17     23.7    0.0472103
# 2018-01-18  17.4172    0.0122951
# 2018-01-19  12.6972     0.137652
# ...             ...          ...
# 2018-05-15  68.4751   -0.0974212
# 2018-05-17  67.1178    0.0280374
# 2018-06-07   17.827  -0.00116144
# 2018-06-11   19.414   -0.0381526
# 2018-06-12  25.2156    -0.155532
#
# [2537 rows x 563 columns]

# %%
# dday_alldf.to_csv('2nd_withopen_stock_2018_10days.csv', index = False)
pd.read_csv('2nd_withopen_stock_2018_10days.csv')
# Out:
#        Code        Date  D-9_Open  D-9_High  D-9_Low  D-9_Close  D-9_Volume  \
# 0     50120  2018-01-15     10250     12050    10150      11800    26086769
# 1     50120  2018-01-16     11950     12450    10900      11750    20460474
# 2     50120  2018-01-17     11850     14150    11600      12600    60663854
# 3     50120  2018-01-18     12800     13200    12000      12200    13935258
# 4     50120  2018-01-19     12450     13400    12350      12850    16471707
# ...     ...         ...       ...       ...      ...        ...         ...
# 2532  11760  2018-05-15     21400     24100    20800      22400     1488904
# 2533  11760  2018-05-17     23500     23850    21950      22350      489326
# 2534  11760  2018-06-07     41650     41900    37000      38800     1305256
# 2535  11760  2018-06-11     40500     41300    40050      41300      712521
# 2536  11760  2018-06-12     42650     44650    39500      40700     2115221
#
#       D-9_Trading_Value  D-9_Change  D-9_MA5  ...  D-0_TSI   D-0_UO   D-0_SR  \
# 0          307823874200    0.145631  10108.0  ...  29.3225  45.3787  63.9228
# 1          240410569500   -0.004237  10538.0  ...  28.0689  45.6406  53.2520
# 2          764364560400    0.072340  11232.0  ...  22.3139  41.0354  25.8130
# 3          170010147600   -0.031746  11730.0  ...  18.8794  41.3833  28.8725
# 4          211661434950    0.053279  12240.0  ...  16.5383  33.5502  25.0000
# ...                 ...         ...      ...  ...      ...      ...      ...
# 2532        33351449600    0.095354  20830.0  ...  56.6722  68.0251  84.6369
# 2533        10936436100   -0.064854  22040.0  ...  54.5403  64.0099  85.1942
# 2534        50643932800   -0.058252  39190.0  ...  29.5457  49.8274  70.6329
# 2535        29427117300    0.298742  38620.0  ...  31.8637  53.8917  95.8333
# 2536        86089494700   -0.014528  38760.0  ...  32.4200  52.7160  75.5020
#
#         D-0_WR        D-0_AO  D-0_KAMA   D-0_ROC   D-0_PPO  D-0_PVO  \
# 0    -36.07720   3645.880000   11858.8  68.67470  12.32460  38.8520
# 1    -46.74800   3980.740000   11947.6  47.78580  12.29020  30.6275
# 2    -74.18700   3687.650000   11946.2  13.10680  10.44330  23.7000
# 3    -71.12750   2987.650000   11947.9   3.38983   9.22399  17.4172
# 4    -75.00000   2637.350000   11949.9   5.10638   8.26069  12.6972
# ...        ...           ...       ...       ...       ...      ...
# 2532 -15.36310   6866.910000   27722.5  74.93730  13.01120  68.4751
# 2533 -14.80580  10338.970588   29517.6  83.12960  15.48880  67.1178
# 2534 -29.36710  10088.100000   36598.8  11.81820  13.02900  17.8270
# 2535  -4.16667  10979.700000   39093.7  20.87380  13.90680  19.4140
# 2536 -24.49800  12323.800000   39605.8  23.45360  14.10110  25.2156
#
#       Next_Change
# 0       -0.068182
# 1       -0.188153
# 2        0.047210
# 3        0.012295
# 4        0.137652
# ...           ...
# 2532    -0.097421
# 2533     0.028037
# 2534    -0.001161
# 2535    -0.038153
# 2536    -0.155532
#
# [2537 rows x 563 columns]
