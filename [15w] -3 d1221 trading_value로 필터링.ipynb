# %%
import pandas as pd

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df = pd.read_feather('d1221.ftr', use_threads = True, columns = None)

# %%
df.columns
# Out:
# Index(['date', 'code', 'D-10_open', 'D-10_high', 'D-10_low', 'D-10_close',
#        'D-10_MA5', 'D-10_MA20', 'D-10_MA60', 'D-10_MA120',
#        ...
#        'D-1_VIpos', 'D-1_ROC', 'D-1_MFI', 'D-1_KCW', 'D-1_BBP', 'D-1_KST',
#        'D-1_DCW', 'D-1_SRSID', 'D-1_PPOhist', 'NextChange'],
#       dtype='object', length=823)

# %%
import numpy as np

# %%
len(df)
# Out:
# 2843050

# %% [markdown]
# # 10억 기준

# %%
# np.argmin(df['D-1_tradingvalue'])
df_filt = df[df['D-1_tradingvalue']>10_0000_0000]

# %%
df_filt = df_filt.reset_index(drop = True)

# %%
df_filt # 수연 shape 1437545
# Out:
#              date    code  D-10_open  D-10_high  D-10_low  D-10_close  \
# 0        20120102  090120  -0.026752   0.128662 -0.100637    0.031847
# 1        20120103  090120   0.009877   0.043210 -0.053086   -0.029630
# 2        20120104  090120  -0.007634   0.059796 -0.071247    0.059796
# 3        20120105  090120   0.068427   0.140456 -0.038415    0.012005
# 4        20120106  090120  -0.027284   0.002372 -0.106762   -0.098458
# ...           ...     ...        ...        ...       ...         ...
# 1439866  20211203  016380   0.000000   0.013699 -0.018265    0.009132
# 1439867  20211206  016380   0.009050   0.054299 -0.004525   -0.004525
# 1439868  20211207  016380   0.004545   0.004545 -0.013636   -0.013636
# 1439869  20211208  016380   0.004608   0.004608 -0.013825   -0.013825
# 1439870  20211209  016380   0.004673   0.009346 -0.037383   -0.032710
#
#          D-10_MA5  D-10_MA20  D-10_MA60  D-10_MA120  ...  D-1_VIpos   D-1_ROC  \
# ...

# %%
df_filt.to_feather('d1221_10thr.ftr')
